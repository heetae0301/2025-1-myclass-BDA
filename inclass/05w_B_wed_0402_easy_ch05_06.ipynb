# %% [markdown]
# <a href="https://colab.research.google.com/github/heetae0301/2025-1-myclass-BDA/blob/main/inclass/05w_B_wed_0402_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd
import pandas as pd

# %%
df_raw=pd.DataFrame({'var1':[1,2,1],'var2':[2,3,2],'var3':[10,20,30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df=df_raw
df.iloc[1,1]=100
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2   100    20
# 2     1     2    30

# %%
df_new=df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2   100    20
# 2     1     2    30

# %%
df_new.rename(columns={'var2':'v2'})
# Out:
#    var1   v2  var3
# 0     1    2    10
# 1     2  100    20
# 2     1    2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2   100    20
# 2     1     2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2   100    20
# 2     1     2    30

# %%
df_new.rename(index={0:"x",1:"y",2:"z"}, inplace=True)
df_new
# Out:
#    var1  var2  var3
# x     1     2    10
# y     2   100    20
# z     1     2    30

# %%
df=pd.DataFrame({"A":[1,2,3], "B":[4,5,6]})
df.rename(columns={"A":"a", "B":"c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# # 파생변수 만들기

# %%
df=pd.DataFrame({'var1':[4,3,8],'var2':[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1=df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum']=df1['var1']+df1['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1["var_mean"]=(df1["var1"]+df1["var2"])/2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2=df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum']=df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %% [markdown]
# #mpg 통합변수 만들기

# %%
import pandas as pd
# Cloning the repository containing mpg.csv
# !git clone https://github.com/ai7dnn/data.git
# Specifying the path to mpg.csv within the cloned repository
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.22 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
# ...

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mpg_mean
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
